# %% [markdown]
# # Indices

# %%
import pandas as pd
from numpy.random import randn

# %%
df = pd.DataFrame(data=randn(5,4), index=["A", "B", "C", "D", "E"], columns="W Y X Z".split())

# %%
df
# Out:
#           W         Y         X         Z
# A  2.516942 -2.625826 -0.764562 -0.418313
# B -0.913376 -0.247576 -2.226710 -0.502607
# C  1.366537 -1.530615 -0.151250 -1.258850
# D  0.247025 -0.366129 -0.271618  0.120543
# E -2.118082  0.379457 -0.079831  0.978484

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'Y', 'X', 'Z'], dtype='object')

# %%
df.reset_index()
# Out:
#   index         W         Y         X         Z
# 0     A  2.516942 -2.625826 -0.764562 -0.418313
# 1     B -0.913376 -0.247576 -2.226710 -0.502607
# 2     C  1.366537 -1.530615 -0.151250 -1.258850
# 3     D  0.247025 -0.366129 -0.271618  0.120543
# 4     E -2.118082  0.379457 -0.079831  0.978484

# %%
df
# Out:
#           W         Y         X         Z
# A  2.516942 -2.625826 -0.764562 -0.418313
# B -0.913376 -0.247576 -2.226710 -0.502607
# C  1.366537 -1.530615 -0.151250 -1.258850
# D  0.247025 -0.366129 -0.271618  0.120543
# E -2.118082  0.379457 -0.079831  0.978484

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   index         W         Y         X         Z
# 0     A  2.516942 -2.625826 -0.764562 -0.418313
# 1     B -0.913376 -0.247576 -2.226710 -0.502607
# 2     C  1.366537 -1.530615 -0.151250 -1.258850
# 3     D  0.247025 -0.366129 -0.271618  0.120543
# 4     E -2.118082  0.379457 -0.079831  0.978484

# %%
df.set_index("index", inplace=True)

# %%
df
# Out:
#               W         Y         X         Z
# index
# A      2.516942 -2.625826 -0.764562 -0.418313
# B     -0.913376 -0.247576 -2.226710 -0.502607
# C      1.366537 -1.530615 -0.151250 -1.258850
# D      0.247025 -0.366129 -0.271618  0.120543
# E     -2.118082  0.379457 -0.079831  0.978484

# %%
novoind = "CA NY WY OR CO".split()

# %%
df["novoind"] = novoind

# %%
df
# Out:
#               W         Y         X         Z novoind
# index
# A      2.516942 -2.625826 -0.764562 -0.418313      CA
# B     -0.913376 -0.247576 -2.226710 -0.502607      NY
# C      1.366537 -1.530615 -0.151250 -1.258850      WY
# D      0.247025 -0.366129 -0.271618  0.120543      OR
# E     -2.118082  0.379457 -0.079831  0.978484      CO

# %%
df.reset_index().set_index("novoind")
# Out:
#         index         W         Y         X         Z
# novoind
# CA          A  2.516942 -2.625826 -0.764562 -0.418313
# NY          B -0.913376 -0.247576 -2.226710 -0.502607
# WY          C  1.366537 -1.530615 -0.151250 -1.258850
# OR          D  0.247025 -0.366129 -0.271618  0.120543
# CO          E -2.118082  0.379457 -0.079831  0.978484
